# %% [markdown]
# # Lesson 0 APCS 第一堂課：程度檢測 Notebook
#
# 這份 notebook 用來確認目前的 Python 基礎。
#
# 使用方式：
#
# 1. 看題目。
# 2. 修改 `return None`。
# 3. 執行下面的 check cell。
# 4. 看到 `✅ pass` 代表通過。
# 5. 看到 `❌ fail` 代表還要修改。
#
# 注意：這不是正式考試，不會也沒關係。

# %% [markdown]
# ## 怎麼填答案？
#
# 例如：
#
# ```python
# def add(a, b):
#     return None
# ```
#
# 可以改成：
#
# ```python
# def add(a, b):
#     return a + b
# ```
#
# 今天大部分題目請使用 `return`，不要只用 `print()`。

# %% [markdown]
# ---
# # Part A. 快速概念檢查
# 請先用眼睛看，猜猜看輸出，再執行。

# %%
# A1. input() 讀進來的型態
x = int("123")
print(type(x))
# Out:
# <class 'int'>

# %%
# A2. = 和 == 不一樣
x = 10
print(x == "10")
# Out:
# False

# %%
# A3. // 和 %
a = 7
b = 3

print(a // b) # -> 7 = 3 * 2 + 1 
print(a % b)
# Out:
# 2
# 1

# %%
7/3
# Out:
# 2.3333333333333335

# %%
# A4. range(3)
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
# A5. 字串相加
a = "3"
b = "4"
print(a + b)
# Out:
# 34

# %% [markdown]
# ---
# # Part B. 實作檢測題

# %% [markdown]
# ## Q1. 問候語
#
# 完成 `q1_greet(name)`，回傳問候語。
#
# 提示：可以使用字串相加。

# %%
def q1_greet(name):
    # TODO: 回傳問候語
    return "Hello, " + name + "!"

# %%
# Check cell：請執行這格確認是否通過
# 這格不列出測試案例的答案，避免只針對固定案例寫程式。

import json, hashlib

def _hash_data(x):
    return hashlib.sha256(
        json.dumps(x, ensure_ascii=False, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()

_func = q1_greet
_data = [{'args': ('Mia',), 'hash': 'a7d27e73f3020a34060feaa480cd8cb9f5089f5433d38289465842e615d63fdc'}, {'args': ('Ben',), 'hash': '106f2a903f4f427b84204ad11bf510a6da77e54913c10069a3212de67d3d9dfb'}, {'args': ('小明',), 'hash': 'eef6f0a683d42a77784ce9b280e2b0d1d729a6c1de7d0e0258ada09be24688e2'}, {'args': ('A',), 'hash': '8f905ad16a6cdfc978af23a0fab21f90f2d38d3b9d981e1f6068fb4b865ee1df'}]

_ok = True

for _i, _case in enumerate(_data, start=1):
    try:
        _args = _case["args"]
        _value = _func(*_args)
        if _hash_data({"args": _args, "expected": _value}) != _case["hash"]:
            print(f"❌ case {_i} fail")
            _ok = False
    except Exception as e:
        print(f"⚠️ case {_i} error:", type(e).__name__)
        _ok = False

if _ok:
    print("✅ Q1 pass")
else:
    print("請修改上面的函式後，再重新執行這格。")
# Out:
# ✅ Q1 pass

# %% [markdown]
# ## Q2. 計算總價
#
# 完成 `q2_total(price, count)`，回傳單價乘以數量。
#
# 提示：乘法使用 `*`。

# %%
def q2_total(price, count):
    # TODO: 回傳總價
    return None

# %%
# Check cell：請執行這格確認是否通過
# 這格不列出測試案例的答案，避免只針對固定案例寫程式。

import json, hashlib

def _hash_data(x):
    return hashlib.sha256(
        json.dumps(x, ensure_ascii=False, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()

_func = q2_total
_data = [{'args': (30, 4), 'hash': '11f6bbdc08c3c89b308337f1a2899155233f7fe31173e00c8eeae970906a6199'}, {'args': (17, 6), 'hash': 'ed60797532371790fbdf7a23d476bce1aa1a8d195af7e5ac91c603f29338f4cc'}, {'args': (0, 9), 'hash': '9eb92efe36c3714a3e4eba3f5f6905d76ba6f4b276866a06cd57d6835b440b0c'}, {'args': (5, 0), 'hash': '25c74b8a651386f9e84f2e8eda20b61398222ae73310d223dfa2be21c6f45db6'}]

_ok = True

for _i, _case in enumerate(_data, start=1):
    try:
        _args = _case["args"]
        _value = _func(*_args)
        if _hash_data({"args": _args, "expected": _value}) != _case["hash"]:
            print(f"❌ case {_i} fail")
            _ok = False
    except Exception as e:
        print(f"⚠️ case {_i} error:", type(e).__name__)
        _ok = False

if _ok:
    print("✅ Q2 pass")
else:
    print("請修改上面的函式後，再重新執行這格。")

# %% [markdown]
# ## Q3. 分組問題
#
# 完成 `q3_group(n, k)`，回傳一個串列，內容是「可以分幾組」和「剩下幾個」。
#
# 提示：`//` 和 `%` 可能會用到。

# %%
def q3_group(n, k):
    # TODO: 回傳 [可以分幾組, 剩下幾個]
    return None

# %%
# Check cell：請執行這格確認是否通過
# 這格不列出測試案例的答案，避免只針對固定案例寫程式。

import json, hashlib

def _hash_data(x):
    return hashlib.sha256(
        json.dumps(x, ensure_ascii=False, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()

_func = q3_group
_data = [{'args': (23, 5), 'hash': 'abb4ce5b1b793658b78c1f6834c9ec75cbbf18d0d9779016809d7056750759c8'}, {'args': (100, 9), 'hash': '7ea065a2a0212647a953e19471671695bc7244c7411fc526b66d4fb4400b7925'}, {'args': (8, 4), 'hash': '753a59bf5c8d7cca57e4a854a2f3ae605033b348c6c16e4305dc7bbbd185fa29'}, {'args': (2, 5), 'hash': '7175ab91601918de4846eff82deaf367d11431cdf2d18b31d6d2eb6b7df50dfe'}]

_ok = True

for _i, _case in enumerate(_data, start=1):
    try:
        _args = _case["args"]
        _value = _func(*_args)
        if _hash_data({"args": _args, "expected": _value}) != _case["hash"]:
            print(f"❌ case {_i} fail")
            _ok = False
    except Exception as e:
        print(f"⚠️ case {_i} error:", type(e).__name__)
        _ok = False

if _ok:
    print("✅ Q3 pass")
else:
    print("請修改上面的函式後，再重新執行這格。")

# %% [markdown]
# ## Q4. 判斷是否及格
#
# 完成 `q4_pass(score)`，分數達到及格標準時回傳 `True`，否則回傳 `False`。
#
# 提示：比較運算會產生布林值。

# %%
def q4_pass(score):
    # TODO: 回傳 True 或 False
    return None

# %%
# Check cell：請執行這格確認是否通過
# 這格不列出測試案例的答案，避免只針對固定案例寫程式。

import json, hashlib

def _hash_data(x):
    return hashlib.sha256(
        json.dumps(x, ensure_ascii=False, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()

_func = q4_pass
_data = [{'args': (60,), 'hash': '87d0ddc08aa07fa6eb6c4bffa5cd8f1845bf727652c12bff472b36d25342d25a'}, {'args': (100,), 'hash': 'd98d666ee1c7dddf234130411f70ae869479cdddd76cd241411100cfcf9d3f42'}, {'args': (59,), 'hash': '1133feedb41a6a68b45c83882b434d1bcb14aeb9344292ed9ee5b1cdcc130c82'}, {'args': (0,), 'hash': '256bef38294432d9560dd7decd0200e9b6a28cd568ae36b93ceef617e903ea50'}, {'args': (61,), 'hash': 'd8b02779035dd86c9b679221e6df54c9ba29197718147da8c6272a635ddd4c4f'}]

_ok = True

for _i, _case in enumerate(_data, start=1):
    try:
        _args = _case["args"]
        _value = _func(*_args)
        if _hash_data({"args": _args, "expected": _value}) != _case["hash"]:
            print(f"❌ case {_i} fail")
            _ok = False
    except Exception as e:
        print(f"⚠️ case {_i} error:", type(e).__name__)
        _ok = False

if _ok:
    print("✅ Q4 pass")
else:
    print("請修改上面的函式後，再重新執行這格。")

# %% [markdown]
# ## Q5. 判斷奇偶數
#
# 完成 `q5_even_or_odd(n)`，根據數字是偶數或奇數回傳對應文字。
#
# 提示：可以觀察除以 2 的餘數。

# %%
def q5_even_or_odd(n):
    # TODO: 偶數回傳 "even"，奇數回傳 "odd"
    return None

# %%
# Check cell：請執行這格確認是否通過
# 這格不列出測試案例的答案，避免只針對固定案例寫程式。

import json, hashlib

def _hash_data(x):
    return hashlib.sha256(
        json.dumps(x, ensure_ascii=False, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()

_func = q5_even_or_odd
_data = [{'args': (2,), 'hash': 'a827dda8240cf570c2facf51330c55055aa06406115dc64063b93b668afc00db'}, {'args': (7,), 'hash': '8e0f40aa32731ecd7041f822d8939e5315dc8b333bed8f6b8982528a8c9f4db1'}, {'args': (0,), 'hash': '132e21a4c8e9ae2155ce707aa5f077d297ae39621c97e3dfa1ccffc2d5786622'}, {'args': (-3,), 'hash': '708342cef3c7c8d7304b9b0df917878713baa32a60e41f57399ad83b9b06e96b'}, {'args': (1024,), 'hash': 'b23236ec0ec70dd9ed86737ae483dd20ba605b7eae6477082a976d8b90d8b949'}, {'args': (99,), 'hash': '6dafde8a8251e456b14f44c46d40f2213767ae4b89c870b4dc01ba61cb82b144'}]

_ok = True

for _i, _case in enumerate(_data, start=1):
    try:
        _args = _case["args"]
        _value = _func(*_args)
        if _hash_data({"args": _args, "expected": _value}) != _case["hash"]:
            print(f"❌ case {_i} fail")
            _ok = False
    except Exception as e:
        print(f"⚠️ case {_i} error:", type(e).__name__)
        _ok = False

if _ok:
    print("✅ Q5 pass")
else:
    print("請修改上面的函式後，再重新執行這格。")

# %% [markdown]
# ## Q6. 找三個數字中的最大值
#
# 完成 `q6_max3(a, b, c)`，回傳三個數字中最大的數字。
#
# 提示：可以用條件判斷，也可以使用內建函式。

# %%
def q6_max3(a, b, c):
    # TODO: 回傳最大值
    return None

# %%
# Check cell：請執行這格確認是否通過
# 這格不列出測試案例的答案，避免只針對固定案例寫程式。

import json, hashlib

def _hash_data(x):
    return hashlib.sha256(
        json.dumps(x, ensure_ascii=False, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()

_func = q6_max3
_data = [{'args': (1, 2, 3), 'hash': '0372389e0a3bcf19589bb38dbb7603ca5a7c2535cc16e5ecad26ea9b01ff9c8b'}, {'args': (10, 2, 3), 'hash': 'ac722f13f348c00a2ae65fb63a9a79208feaed0481e4c1ca746b5194c503fa71'}, {'args': (-1, -5, -3), 'hash': '2990849badf3f0c09a1386e564fd6f20e0e156333d2cf172a4c73705ccdf2a53'}, {'args': (4, 4, 2), 'hash': 'f8597df32a2238c5bd2a11df52e815502188bc9ed5b68ee53f92e0888e2b1523'}, {'args': (5, 9, 9), 'hash': '03a59313b12bcae1098c16472c67e08c5eed11780db7b36cf675632a7269e120'}]

_ok = True

for _i, _case in enumerate(_data, start=1):
    try:
        _args = _case["args"]
        _value = _func(*_args)
        if _hash_data({"args": _args, "expected": _value}) != _case["hash"]:
            print(f"❌ case {_i} fail")
            _ok = False
    except Exception as e:
        print(f"⚠️ case {_i} error:", type(e).__name__)
        _ok = False

if _ok:
    print("✅ Q6 pass")
else:
    print("請修改上面的函式後，再重新執行這格。")

# %% [markdown]
# ## Q7. 加總串列
#
# 完成 `q7_sum_list(nums)`，回傳串列內所有數字的總和。
#
# 提示：可以用迴圈逐一處理。

# %%
def q7_sum_list(nums):
    # TODO: 回傳總和
    return None

# %%
# Check cell：請執行這格確認是否通過
# 這格不列出測試案例的答案，避免只針對固定案例寫程式。

import json, hashlib

def _hash_data(x):
    return hashlib.sha256(
        json.dumps(x, ensure_ascii=False, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()

_func = q7_sum_list
_data = [{'args': ([1, 2, 3],), 'hash': 'fa9080d8eb8ed119423c4514139bef18a21c59ab3ec2dfb2724e78cee0ccbe32'}, {'args': ([10, -3, 5],), 'hash': '9ac428f5cdd9e4445d3c5e07eb8efdbf98e9b1929e572725ad65a89d096e629d'}, {'args': ([],), 'hash': '502a51afed4aa7ff2899b5b8179d3f179c95685626a67fbcff1da0fc49968cdd'}, {'args': ([-1, -2, -3],), 'hash': '1ea670c75c5161d953ff28349ff9311fc4aea2ae5c9fb16c1ac3c5e6c67bf394'}, {'args': ([100],), 'hash': 'b49e99e87de8ec7c87d59acd22d972bc708a9ace55fd8966e8d0493eb7a5a3fa'}]

_ok = True

for _i, _case in enumerate(_data, start=1):
    try:
        _args = _case["args"]
        _value = _func(*_args)
        if _hash_data({"args": _args, "expected": _value}) != _case["hash"]:
            print(f"❌ case {_i} fail")
            _ok = False
    except Exception as e:
        print(f"⚠️ case {_i} error:", type(e).__name__)
        _ok = False

if _ok:
    print("✅ Q7 pass")
else:
    print("請修改上面的函式後，再重新執行這格。")

# %% [markdown]
# ## Q8. 計算及格人數
#
# 完成 `q8_count_pass(scores)`，回傳串列中達到及格標準的人數。
#
# 提示：可以使用計數變數。

# %%
def q8_count_pass(scores):
    # TODO: 回傳及格人數
    return None

# %%
# Check cell：請執行這格確認是否通過
# 這格不列出測試案例的答案，避免只針對固定案例寫程式。

import json, hashlib

def _hash_data(x):
    return hashlib.sha256(
        json.dumps(x, ensure_ascii=False, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()

_func = q8_count_pass
_data = [{'args': ([100, 50, 80, 30],), 'hash': '99400c62189cec58a59b141f2b727b5c3cada9beb9b6ea95d8944de0daeda71d'}, {'args': ([60, 60, 59],), 'hash': '122a63164618eb40dbfba5341d83d11d8ce9a04da2c5fcd109c6598165a0b3bc'}, {'args': ([],), 'hash': '502a51afed4aa7ff2899b5b8179d3f179c95685626a67fbcff1da0fc49968cdd'}, {'args': ([0, 10, 20],), 'hash': '6fd1d25009f0b0dadcd9a4e65b79968fc10945d77f59a1bb6f4f9c90ee01a718'}, {'args': ([61, 99, 100, 60],), 'hash': '2b25997c851a2b0f4d9748d7791e02741e9b44fe58c577ba691c76c37e21bc64'}]

_ok = True

for _i, _case in enumerate(_data, start=1):
    try:
        _args = _case["args"]
        _value = _func(*_args)
        if _hash_data({"args": _args, "expected": _value}) != _case["hash"]:
            print(f"❌ case {_i} fail")
            _ok = False
    except Exception as e:
        print(f"⚠️ case {_i} error:", type(e).__name__)
        _ok = False

if _ok:
    print("✅ Q8 pass")
else:
    print("請修改上面的函式後，再重新執行這格。")

# %% [markdown]
# ## Q9. 字典查詢
#
# 完成 `q9_get_score(score_dict, name)`。如果名字存在，回傳分數；如果不存在，回傳指定文字。
#
# 提示：可以用 `in` 判斷 key 是否存在。

# %%
def q9_get_score(score_dict, name):
    # TODO: 如果 name 存在，回傳分數；否則回傳 "not found"
    return None

# %%
# Check cell：請執行這格確認是否通過
# 這格不列出測試案例的答案，避免只針對固定案例寫程式。

import json, hashlib

def _hash_data(x):
    return hashlib.sha256(
        json.dumps(x, ensure_ascii=False, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()

_func = q9_get_score
_data = [{'args': ({'Tom': 80, 'Amy': 90}, 'Tom'), 'hash': '941fa3b38007689fc78bd18bd1c69b3d57f3c899609638b3f6e3f085d0302289'}, {'args': ({'Tom': 80, 'Amy': 90}, 'Amy'), 'hash': '4bd1a7620540a2aba65bc05a63a35dd5147c6c3d089a64fb6f5438b21243b0e3'}, {'args': ({'Tom': 80, 'Amy': 90}, 'Ben'), 'hash': '064586f3521e907c0f6d5b7d361708687b3161f3d94b7213c03f45d66cd2dd9a'}, {'args': ({}, 'Tom'), 'hash': 'ae63f5f700900f76ee8bb9bb62f43aa499f8199c89bb65867810e7dad689b9fd'}]

_ok = True

for _i, _case in enumerate(_data, start=1):
    try:
        _args = _case["args"]
        _value = _func(*_args)
        if _hash_data({"args": _args, "expected": _value}) != _case["hash"]:
            print(f"❌ case {_i} fail")
            _ok = False
    except Exception as e:
        print(f"⚠️ case {_i} error:", type(e).__name__)
        _ok = False

if _ok:
    print("✅ Q9 pass")
else:
    print("請修改上面的函式後，再重新執行這格。")

# %% [markdown]
# ## Q10. 安全轉整數
#
# 完成 `q10_safe_int(s)`。如果可以轉成整數就回傳轉換結果；如果不能，回傳 `None`。
#
# 提示：可以使用 `try` / `except`。

# %%
def q10_safe_int(s):
    # TODO: 可以轉成整數就回傳轉換結果；不能就回傳 None
    return None

# %%
# Check cell：請執行這格確認是否通過
# 這格不列出測試案例的答案，避免只針對固定案例寫程式。

import json, hashlib

def _hash_data(x):
    return hashlib.sha256(
        json.dumps(x, ensure_ascii=False, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()

_func = q10_safe_int
_data = [{'args': ('123',), 'hash': '43c8f2396104520c87f26e44987994a994035e53c1906615cd4c28c575b7cac2'}, {'args': ('-5',), 'hash': '1c8f84065f59f2472b61900a76a58b14561cc8ed93e0dfe735f3863c41b01b23'}, {'args': ('abc',), 'hash': '2575a3c1bb0862b34a5ef33d6d5ef7580671ec76d848d4b231d27e910c557f03'}, {'args': ('0',), 'hash': 'ce447e2e3496b9ce5e16efed60cc06bd01969968b2b7af21f0775f120644d91e'}, {'args': ('12.3',), 'hash': 'd0c4a0ebb6e8b7ac3231c64a59026a8d6f5ababd27e857b60680091940340ee5'}]

_ok = True

for _i, _case in enumerate(_data, start=1):
    try:
        _args = _case["args"]
        _value = _func(*_args)
        if _hash_data({"args": _args, "expected": _value}) != _case["hash"]:
            print(f"❌ case {_i} fail")
            _ok = False
    except Exception as e:
        print(f"⚠️ case {_i} error:", type(e).__name__)
        _ok = False

if _ok:
    print("✅ Q10 pass")
else:
    print("請修改上面的函式後，再重新執行這格。")
